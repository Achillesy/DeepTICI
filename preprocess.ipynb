# %%
import os
import pydicom

import matplotlib.pyplot as plt

# %%
curpath = os.getcwd()
workpath = curpath.split("Workspace")[0]
gData = os.path.join(workpath, "Workspace", "DataSet")
DSA_path = os.path.join(gData, "DiveMed", "DB_images", "Rush")

# %%
file_0001_11 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927141501723.1005.9.7334_0001_110000_16981757850000.dcm")
dcm_0001_11 = pydicom.read_file(file_0001_11)
img_0001_11 = dcm_0001_11.pixel_array
print(dcm_0001_11.PatientID, dcm_0001_11.PatientName)
print(dcm_0001_11.ImageType, img_0001_11.shape)

file_0001_12 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927141501723.1005.9.7334_0001_120000_16981757880001.dcm")
dcm_0001_12 = pydicom.read_file(file_0001_12)
img_0001_12 = dcm_0001_12.pixel_array
print(dcm_0001_12.PatientID, dcm_0001_12.PatientName)
print(dcm_0001_12.ImageType, img_0001_12.shape)

fig, axes = plt.subplots(1, 2)
axes[0].imshow(img_0001_11[11], cmap="bone")
axes[1].imshow(img_0001_12[11], cmap="bone")
plt.show()
# Out:
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE A', 'DSA', 'ACQ'] (22, 1024, 1024)
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE B', 'DSA', 'ACQ'] (22, 1024, 1024)

# %%
file_0002_21 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927141610851.1011.7.7724_0002_210000_16981758460067.dcm")
dcm_0002_21 = pydicom.read_file(file_0002_21)
img_0002_21 = dcm_0002_21.pixel_array
print(dcm_0002_21.PatientID, dcm_0002_21.PatientName)
print(dcm_0002_21.ImageType, img_0002_21.shape)

file_0002_22 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927141610851.1011.7.7724_0002_220000_16981758470068.dcm")
dcm_0002_22 = pydicom.read_file(file_0002_22)
img_0002_22 = dcm_0002_22.pixel_array
print(dcm_0002_22.PatientID, dcm_0002_22.PatientName)
print(dcm_0002_22.ImageType, img_0002_22.shape)

fig, axes = plt.subplots(1, 2)
axes[0].imshow(img_0002_21[10], cmap="bone")
axes[1].imshow(img_0002_22[10], cmap="bone")
plt.show()
# Out:
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE A', 'DSA', 'ACQ'] (21, 1024, 1024)
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE B', 'DSA', 'ACQ'] (21, 1024, 1024)

# %%
file_0003_31 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927141913504.1017.6.9962_0003_310000_1698175810005a.dcm")
dcm_0003_31 = pydicom.read_file(file_0003_31)
img_0003_31 = dcm_0003_31.pixel_array
print(dcm_0003_31.PatientID, dcm_0003_31.PatientName)
print(dcm_0003_31.ImageType, img_0003_31.shape)

file_0003_32 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927141913504.1017.6.9962_0003_320000_1698175812005b.dcm")
dcm_0003_32 = pydicom.read_file(file_0003_32)
img_0003_32 = dcm_0003_32.pixel_array
print(dcm_0003_32.PatientID, dcm_0003_32.PatientName)
print(dcm_0003_32.ImageType, img_0003_32.shape)

fig, axes = plt.subplots(1, 2)
axes[0].imshow(img_0003_31[11], cmap="bone")
axes[1].imshow(img_0003_32[11], cmap="bone")
plt.show()
# Out:
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE A', 'DSA', 'ACQ'] (22, 1024, 1024)
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE B', 'DSA', 'ACQ'] (22, 1024, 1024)

# %%
file_0004_41 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927142022419.1023.0.2145_0004_410000_16981758510074.dcm")
dcm_0004_41 = pydicom.read_file(file_0004_41)
img_0004_41 = dcm_0004_41.pixel_array
print(dcm_0004_41.PatientID, dcm_0004_41.PatientName)
print(dcm_0004_41.ImageType, img_0004_41.shape)

file_0004_42 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927142022419.1023.0.2145_0004_420000_16981758530075.dcm")
dcm_0004_42 = pydicom.read_file(file_0004_42)
img_0004_42 = dcm_0004_42.pixel_array
print(dcm_0004_42.PatientID, dcm_0004_42.PatientName)
print(dcm_0004_42.ImageType, img_0004_42.shape)

fig, axes = plt.subplots(1, 2)
axes[0].imshow(img_0004_41[9], cmap="bone")
axes[1].imshow(img_0004_42[9], cmap="bone")
plt.show()
# Out:
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE A', 'DSA', 'ACQ'] (19, 1024, 1024)
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE B', 'DSA', 'ACQ'] (19, 1024, 1024)

# %%
file_0005_51 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927142344551.1029.0.1961_0005_510000_169817586600a6.dcm")
dcm_0005_51 = pydicom.read_file(file_0005_51)
img_0005_51 = dcm_0005_51.pixel_array
print(dcm_0005_51.PatientID, dcm_0005_51.PatientName)
print(dcm_0005_51.ImageType, img_0005_51.shape)

file_0005_52 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927142344551.1029.0.1961_0005_520000_169817586700a7.dcm")
dcm_0005_52 = pydicom.read_file(file_0005_52)
img_0005_52 = dcm_0005_52.pixel_array
print(dcm_0005_52.PatientID, dcm_0005_52.PatientName)
print(dcm_0005_52.ImageType, img_0005_52.shape)

fig, axes = plt.subplots(1, 2)
axes[0].imshow(img_0005_51[9], cmap="bone")
axes[1].imshow(img_0005_52[9], cmap="bone")
plt.show()
# Out:
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE A', 'DSA', 'ACQ'] (19, 1024, 1024)
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE B', 'DSA', 'ACQ'] (19, 1024, 1024)

# %%
file_0006_61 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927144306038.1035.1.3942_0006_610000_16981758070052.dcm")
dcm_0006_61 = pydicom.read_file(file_0006_61)
img_0006_61 = dcm_0006_61.pixel_array
print(dcm_0006_61.PatientID, dcm_0006_61.PatientName)
print(dcm_0006_61.ImageType, img_0006_61.shape)

file_0006_62 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927144306038.1035.1.3942_0006_620000_16981758080053.dcm")
dcm_0006_62 = pydicom.read_file(file_0006_62)
img_0006_62 = dcm_0006_62.pixel_array
print(dcm_0006_62.PatientID, dcm_0006_62.PatientName)
print(dcm_0006_62.ImageType, img_0006_62.shape)

fig, axes = plt.subplots(1, 2)
axes[0].imshow(img_0006_61[6], cmap="bone")
axes[1].imshow(img_0006_62[6], cmap="bone")
plt.show()
# Out:
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE A', 'DSA', 'ACQ'] (12, 1024, 1024)
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE B', 'DSA', 'ACQ'] (12, 1024, 1024)

# %%
file_0007_71 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927144611541.1041.8.6391_0007_710000_169817586300a0.dcm")
dcm_0007_71 = pydicom.read_file(file_0007_71)
img_0007_71 = dcm_0007_71.pixel_array
print(dcm_0007_71.PatientID, dcm_0007_71.PatientName)
print(dcm_0007_71.ImageType, img_0007_71.shape)

file_0007_72 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927144611541.1041.8.6391_0007_720000_169817586400a1.dcm")
dcm_0007_72 = pydicom.read_file(file_0007_72)
img_0007_72 = dcm_0007_72.pixel_array
print(dcm_0007_72.PatientID, dcm_0007_72.PatientName)
print(dcm_0007_72.ImageType, img_0007_72.shape)

fig, axes = plt.subplots(1, 2)
axes[0].imshow(img_0007_71[7], cmap="bone")
axes[1].imshow(img_0007_72[7], cmap="bone")
plt.show()
# Out:
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE A', 'DSA', 'ACQ'] (14, 1024, 1024)
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE B', 'DSA', 'ACQ'] (14, 1024, 1024)

# %%
file_0008_81 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927144744302.1047.8.1153_0008_810000_1698175848006e.dcm")
dcm_0008_81 = pydicom.read_file(file_0008_81)
img_0008_81 = dcm_0008_81.pixel_array
print(dcm_0008_81.PatientID, dcm_0008_81.PatientName)
print(dcm_0008_81.ImageType, img_0008_81.shape)

file_0008_82 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927144744302.1047.8.1153_0008_820000_1698175849006f.dcm")
dcm_0008_82 = pydicom.read_file(file_0008_82)
img_0008_82 = dcm_0008_82.pixel_array
print(dcm_0008_82.PatientID, dcm_0008_82.PatientName)
print(dcm_0008_82.ImageType, img_0008_82.shape)

fig, axes = plt.subplots(1, 2)
axes[0].imshow(img_0008_81[6], cmap="bone")
axes[1].imshow(img_0008_82[6], cmap="bone")
plt.show()
# Out:
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE A', 'DSA', 'ACQ'] (13, 1024, 1024)
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE B', 'DSA', 'ACQ'] (13, 1024, 1024)

# %%
file_0009_91 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927152458791.1058.5.2718_0009_910000_1698175861009a.dcm")
dcm_0009_91 = pydicom.read_file(file_0009_91)
img_0009_91 = dcm_0009_91.pixel_array
print(dcm_0009_91.PatientID, dcm_0009_91.PatientName)
print(dcm_0009_91.ImageType, img_0009_91.shape)

file_0009_92 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927152458791.1058.5.2718_0009_920000_1698175861009b.dcm")
dcm_0009_92 = pydicom.read_file(file_0009_92)
img_0009_92 = dcm_0009_92.pixel_array
print(dcm_0009_92.PatientID, dcm_0009_92.PatientName)
print(dcm_0009_92.ImageType, img_0009_92.shape)

fig, axes = plt.subplots(1, 2)
axes[0].imshow(img_0009_91[6], cmap="bone")
axes[1].imshow(img_0009_92[6], cmap="bone")
plt.show()
# Out:
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE A', 'DSA', 'ACQ'] (13, 1024, 1024)
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE B', 'DSA', 'ACQ'] (13, 1024, 1024)

# %%
file_0011_11 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927154251706.1074.0.2912_0011_1110000_169817586900ac.dcm")
dcm_0011_11 = pydicom.read_file(file_0011_11)
img_0011_11 = dcm_0011_11.pixel_array
print(dcm_0011_11.PatientID, dcm_0011_11.PatientName)
print(dcm_0011_11.ImageType, img_0011_11.shape)

file_0011_12 = os.path.join(DSA_path, "1.2.392.200036.9116.3.1.12582476.20230927154251706.1074.0.2912_0011_1120000_169817587100ad.dcm")
dcm_0011_12 = pydicom.read_file(file_0011_12)
img_0011_12 = dcm_0011_12.pixel_array
print(dcm_0011_12.PatientID, dcm_0011_12.PatientName)
print(dcm_0011_12.ImageType, img_0011_12.shape)

fig, axes = plt.subplots(1, 2)
axes[0].imshow(img_0011_11[10], cmap="bone")
axes[1].imshow(img_0011_12[10], cmap="bone")
plt.show()
# Out:
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE A', 'DSA', 'ACQ'] (21, 1024, 1024)
# 8740638 CAPLIN^PHOEBE SELENE^^^
# ['DERIVED', 'SECONDARY', 'BIPLANE B', 'DSA', 'ACQ'] (21, 1024, 1024)
